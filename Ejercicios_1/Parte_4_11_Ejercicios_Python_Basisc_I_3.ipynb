# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %%
A = 4
B = "Text"
C = 4.1
print((lambda: "A y B son equivalentes" if A == B else "A y B NO son equivalentes")())
print((lambda: "A y C son equivalentes" if A == C else "A y C NO son equivalentes")())
print((lambda: "Sí, A es mayor que C" if A > C else "NO, A NO es mayor que C")())
print((lambda: "Sí, C es menor o igual que que A" if C <= A else "NO, C NO es menor o igual que A")())
print((lambda: "B es equivalente a C" if B == C else "B NO es equivalente a C")())
# Out:
# A y B NO son equivalentes
# A y C NO son equivalentes
# NO, A NO es mayor que C
# NO, C NO es menor o igual que A
# B NO es equivalente a C

# %%
var1 = input("Ingresa un dato: ")
var2 = input("Ingresa otro dato: ")
print((lambda: "Los datos ingresados son iguales" if var1 == var2 else "Los datos ingresados NO son equivalentes")())
# Out:
# Los datos ingresados NO son equivalentes

# %%
var1 = input("Ingresa un dato: ")
var2 = input("Ingresa otro dato: ")
var3 = input("Ingresa otro dato: ")

todos_iguales = var1 == var2 == var3
if todos_iguales:
    print("Todos los datos son iguales")
else:
    print("No todos los datos son iguales")


al_menos_dos = (var1 == var2) or (var1 == var3) or (var2 == var3)
if al_menos_dos:
    print("Al menos dos datos son iguales")
else:
    print("No hay datos iguales")
# Out:
# No todos los datos son iguales
# Al menos dos datos son iguales

# %% [markdown]
# 1) False
# 2) False
# 3) False
# 4) False
